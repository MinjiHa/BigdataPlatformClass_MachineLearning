# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.request import urljoin

content = ""
for i in range(1,100,10):
    url = urlopen('https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&c_id=&c_name=&sm=tab_pge&kin_start='+str(i))
    soup = BeautifulSoup(url, 'html.parser')

    for i in range(0,10):
        q = soup.find_all('dt','question')[i]
        a = soup.find_all('dd','answer')[i]
        content += q.find('a').get_text()
        content += a.get_text()

print(content)
# Out:
# 파이썬인강 어디있나요  답변 파이썬인강은 기초부터 공부하기 좋은걸로 하시는 것이 좋습니다. 조금만 찾아보셔도 파이썬인강은 나올텐데 왠만하면은 파이썬인강을 잘알려줄만한 곳으로 하시는게...  c언어 파이썬 언어로  답변 네, 소스코드 올려주면 확인하고 파이썬으로 변경해드리겠습니다. 지식인 상단에 eXpert 라고 있습니다. 그거 클릭해서 상담 진행해주시면 감사하겠습니다. 네이버...  프로그래밍 파이썬 독학  답변 파이썬공부에 대해 질문 남겨주셨는데요, 우선, 파이썬은 홈페이지 개발에 많이 쓰입니다 윈도우 실행... 쓰입니다 파이썬은 사람이 생각하는 방식을 그대로 표현할 수...  파이썬 저희애가 배우려고 하는데  답변 파이썬도 괜찮지만 어떤거부터 배우면 좋을지와 학원 후기등등 잘 살펴보시면 좋을듯 합니다  파이썬 pip 질문  답변 com/pip-install/ 파이썬 pip 설치 및 옵션 사용법 총정리 - 도라가이드 파이썬 pip 설치 및 사용법에... 파이썬 소프트웨어 패키지를 한 번의 명령어 사용으로...  파이썬 코드 질문  답변 자릿수를 하나씩 버리면서 계산하면 되겠습니다. 어떤 숫자 a 가 있을 때 a를 10으로 나누면 1의 자리가 잘려나가면서 자리수가 줄어드는 것을...  파이썬 질문입니다  답변 다음 예제를 참고하세요. # This Python file uses the following encoding: utf-8 # -*- coding: utf-8 -*- n = int(input('N의 숫자를 입력 : ')) sum = 0 for step in...  파이썬 혼자  답변 파이썬 공부에 대해서 궁금하신거 같아요!! IT관련으로 처음 접하시면 파이썬 독학으로는 힘들고 어려울... com/o/snxdmQcc 배쌤과 함께하는 IT컨설팅 #파이썬...  파이썬교육과정 질문  답변 파이썬교육과정을 공부할 수 있는 학원이 있는지 질문주셨는데요. 먼저 말씀드릴 부분은 성인들이 배우는 파이썬이나 학생들이 배우는 파이썬교육과정...  c언어 파이썬 관련 질문  답변 C언어나 파이썬을 보다 쉽고 재미있게 효율적으로 배우고... 파이썬은 프로그램을 만드는 일인 프로그래밍할 때 사용되는 도구로 프로그래밍 언어입니다. C언어나 파이썬같...  파이썬 독학 어떻게 하나요?  답변 보통 파이썬 독학은 인강으로 하는 경우가 많아요 파이썬 인강으로 KG에듀원 이룸 추천해드릴게요 대부분 파이썬 인강들은 별도로 교재를 구매해야하는 경우가 많은데...  파이썬 for,range  답변 sum=0 for i in range(0,5): number = int(input('enter number : ')) sum +=number print('toatl :',sum)  파이썬 그래프 그리기  답변 #y_coords = [open('해당파일이름.txt')] y_coords = np.loadtxt('파일이름.txt') numpy 모듈을 사용할 수 없다면 파이썬의 기본적 자료형인 list를 사용해야...  파이썬이 쉬운편인가요?  답변 파이썬 프로그래밍은 컴퓨터언어의 일종으로 간결하고... 바이오파이썬은 프로젝트 분자생물학 계산에 자유롭게 사용하기위한 파이썬 라이브러리구축 프로젝트입니다....  파이썬프로그래밍을 배우면 일본취업에 유리할까요?  답변 사실 파이썬은.. 언어 자체의 스킬만 가지고서는 취업이... 그 이유는 파이썬의 경우 보통 처음부터 뭔가 협업하여... 경우에도 파이썬으로 전부 구성하기도 하는데 흔하지는...  파이썬 설치에 대해...  답변 파이썬은 무로입니다. 파이선 자체 설치는 한곳 뿐 입니다. https://www.python.org/downloads/ 이곳에 가셔서 가장 최신버전을 선택 하시면 됩니다. 아톰이나 그런...  파이썬 관련 질문  답변 파이썬이 맞나요? 시작으로는 좋은 선택입니다.... 노트북으로 파이썬을 바우고 싶은데 어느 노트북이... 이용할 수 있는 강좌 파이썬 코딩 도장 시작하기 C 언어...  파이썬 출력 관련  답변 --> 문제의 수식을 그대로 파이썬에 입력한 다음... --> 마찬가지로 문제의 수식을 파이썬에 입력한 다음... --> 이것도 파이썬에 두 command를 실행해보면 됩니다....  파이썬학원 기초부터 하는곳  답변 파이썬은 프로그래밍입문으로 가장 좋은 언어 중... 쉽다는거지, 파이썬도 어렵게 느끼는분들이 생각보다... 진행하고 있는 파이썬교육으로는 파이썬기초...  노트북 인텔 파이썬  답변 질문자님을 뵙게 되어 감사드리며 컴퓨터 하드웨어 분야 1위 / 조립분야 1위 / 그래픽카드 분야 1위로 활동중이며 [2017] / [2018] / [2019] 분야별 지식인 후보로 선정된...  파이썬 만으로 웹사이트 구축 가능한가요??  답변 안녕하세요 온라인 상담을 맡고 있는 재희선생님입니다 웹프로그램을 만들고 싶으시면 프로그래밍언어 파이썬 , C언어, C++ JAVA ,JSP 자료구조 등 HTML,CSS ,등 다양한...  파이썬 독학  답변 질문자님께서 파이썬 언어를 인강으로 공부할려고... IT통합기초를 기본적으로 들어보시고 그다음 파이썬... 학점은행제 #IT통합기초 #파이썬 #C언어 #자바 open.kakao.com  파이썬강좌 어디가 좋죠?  답변 이에요 파이썬강좌 때문에 지식인 올려주신 듯... 파이썬같은 경우, 기초문법 및 활용법을 가르치고... 언어가 파이썬입니다. 인강듣다가 모르는부분이 있으면 1대1...  파이썬 공부는 어떻게 해볼까요??  답변 덕구선생님입니다 파이썬 언어는 문법도 간결하여... 파이썬은 주로 AI와 같은 인공지능이랑... action=view&no=396 KG에듀원 이룸 파이썬언어의 문법적 특성, 키워드와...  파이썬 조건문  답변 from turtle import * a = 1 if a == 1: print('터틀 실행') color('red', 'yellow') begin_fill() while True: forward(200) left(170) if abs(pos()) < 1: break end...  파이썬 질문 급합니다  답변 tuple1 = ('A+','A0','B+','C+','C0','D+','F') newScores = [] for i in tuple1: print(i, end=' ') newScores = list(tuple1[0:5]) print(newScores) for i in...  파이썬학원추천해주세요!!  답변 안녕하세요~ 제가 추천드리는 파이썬학원은 전문적인 강사님들이 파이썬학원 수업을... 있고요 파이썬 실무스킬을 교육적으로 잘 가르칩니다! 아무래도 전문적인 교육기관을...  파이썬 공부하는 방법알려주세요  답변 파이썬을 공부하신다고 하셨는데요~ 일단 냉정하게... 추가적으로, 만약 주위에 파이썬 관련하여 전문가가... limhg999.edueroom.co.kr 파이썬 독학 관련해서 더 궁금하신...  파이썬인강 추천  답변 kg아이티뱅크 조성형부장 입니다 오프라인 교육과 오프라인 교육을 촬영을 해서 실강을 인강으로 교육 받을수 있는 학원 입니다 시간이 되신다면 인강과...  파이썬 책 추천좀.......  답변 ItemId=80277523 Effective Python 이펙티브 파이썬 : 파이썬 코딩의 기술... 최선의 선택인지 조언하며 파이썬 코드를 더 효과적으로 작성... www.aladin.co.kr  파이썬학원 다니고싶어요!  답변 파이썬학원 다녀보시려고 질문글 남겨주셨는데요 저도 파이썬에 흥미가 있어서 이쪽 분야에 최고가 되고 싶어서 파이썬학원 전문적인곳 여러군데 알아봤었습니다....  파이썬 공부  답변 파이썬공부에 대해 질문 남겨주셨는데요, 우선, 파이썬은 홈페이지 개발에 많이 쓰입니다 윈도우 실행... 쓰입니다 파이썬은 사람이 생각하는 방식을 그대로 표현할 수...  파이썬에 대해 잘 아시는 분  답변 파이썬은 외부 라이브러리 등을 통해 엄청 많은 분야를 지원하고 있습니다.... 질문하실땐 사진 캡쳐보다는 파이썬 코드를 텍스트로 캡쳐 하시던가 py파일을 첨부로...  파이썬 질문  답변 레이블의 환경을 구성 또는 설정한다는 의미입니다. 정확하고 신속한 답변을 원하십니까? 정확하고 신속한 답변을 원하십니까? 1. 질 ...

# %%
from konlpy.tag import Okt

okt = Okt()
set(okt.nouns(content))
# Out:
# {'가능',
#  '가요',
#  '가이드',
#  '가장',
#  '가지원',
#  '감사',
#  '값',
#  '강사',
#  '강의',
#  '강좌',
#  '개',
#  '개발',
#  '개발자',
#  '갱신',
#  '거',
#  '거나',
#  '거북이',
#  '거지',
#  '건',
#  '검사',
#  '것',
#  '게',
#  '게임',
#  '경우',
#  '계',
#  '계산',
#  '계속',
#  '곳',
#  '공부',
#  '공역',
#  '공통',
#  '과',
#  '과정',
#  '과제',
#  '관련',
#  '교실',
#  '교육',
#  '교육과정',
#  '교재',
#  '구매',
#  '구문',
#  '구성',
#  '구축',
#  '구현',
#  '국비',
#  '군데',
#  '굳이',
#  '그',
#  '그거',
#  '그다음',
#  '그대로',
#  '그래프',
#  '그래픽',
#  '그래픽카드',
#  '그릇',
#  '그리기',
#  '글',
#  '기관',
#  '기본',
#  '기술',
#  '기초',
#  '나',
#  '난이도',
#  '낱개',
#  '내용',
#  '낼',
#  '너리',
#  '네',
#  '네이버',
#  '노력',
#  '노트북',
#  '다른',
#  '다만',
#  '다음',
#  '단기간',
#  '단순',
#  '담',
#  '답변',
#  '대부분',
#  '대신',
#  '대한',
#  '대해',
#  '더',
#  '덕',
#  '도구로',
#  '도서',
#  '도움',
#  '도장',
#  '독학',
#  '두',
#  '둘',
#  '드릴',
#  '듯',
#  '등',
#  '등등',
#  '등록',
#  '딕셔',
#  '때',
#  '때문',
#  '땐',
#  '라이브러리',
#  '러닝',
#  '레이블',
#  '렌덤',
#  '로',
#  '로그인',
#  '를',
#  '리스트',
#  '링크',
#  '마리',
#  '마음',
#  '마찬가지',
#  '막상막하',
#  '만약',
#  '머리',
#  '먼저',
#  '메',
#  '메인',
#  '메일',
#  '명령어',
#  '몇몇',
#  '모두',
#  '모듈',
#  '모든',
#  '목적',
#  '무',
#  '무작위',
#  '문',
#  '문법',
#  '문자열',
#  '문제',
#  '문제점',
#  '뭐',
#  '뭔가',
#  '및',
#  '바우',
#  '바이오파이썬',
#  '바탕화면',
#  '반복',
#  '반품',
#  '발매',
#  '방문',
#  '방법',
#  '방식',
#  '배쌤',
#  '뱅크',
#  '버전',
#  '번',
#  '번의',
#  '법',
#  '법좀',
#  '변경',
#  '변수',
#  '별',
#  '별도',
#  '보고',
#  '보시',
#  '보이',
#  '보통',
#  '복소수',
#  '볼',
#  '부분',
#  '부산',
#  '부적',
#  '분',
#  '분야',
#  '분자생물학',
#  '불가',
#  '비',
#  '비교',
#  '비밀번호',
#  '뿐',
#  '사람',
#  '사서',
#  '사실',
#  '사용',
#  '사지',
#  '사진',
#  '상단',
#  '상담',
#  '상세',
#  '상용',
#  '상편',
#  '상품',
#  '생',
#  '생각',
#  '생성자',
#  '선생님',
#  '선언',
#  '선정',
#  '선택',
#  '설명',
#  '설정',
#  '설치',
#  '섬',
#  '성공',
#  '성인',
#  '세',
#  '세트',
#  '소스',
#  '소스코드',
#  '소프트웨어',
#  '수',
#  '수가',
#  '수기',
#  '수식',
#  '수업',
#  '수학',
#  '숫자',
#  '스크립트',
#  '스킬',
#  '시',
#  '시간',
#  '시기',
#  '시작',
#  '신청',
#  '실강',
#  '실무',
#  '실수부',
#  '실행',
#  '심화',
#  '아래',
#  '아시',
#  '아이티',
#  '아주',
#  '아톰',
#  '알',
#  '앞',
#  '애가',
#  '얘기',
#  '어디',
#  '어디가',
#  '언어',
#  '업',
#  '에듀',
#  '에러',
#  '여러가지',
#  '연산자',
#  '염소',
#  '영어',
#  '영진닷컴',
#  '영향',
#  '예',
#  '예제',
#  '오류',
#  '오오사',
#  '오프라인',
#  '온라인',
#  '옵션',
#  '완전',
#  '외부',
#  '요',
#  '용법',
#  '우선',
#  '워드',
#  '원인',
#  '웹',
#  '웹사이트',
#  '위',
#  '위로',
#  '윈도우',
#  '은',
#  '의',
#  '의미',
#  '의사',
#  '의사코드',
#  '이',
#  '이름',
#  '이미지',
#  '이용',
#  '이유',
#  '이펙티브',
#  '이해',
#  '이후',
#  '인강',
#  '인공',
#  '인스턴스',
#  '인텔',
#  '일',
#  '일단',
#  '일인',
#  '일종',
#  '입력',
#  '입문',
#  '자',
#  '자동',
#  '자료구조',
#  '자료형',
#  '자리',
#  '자릿',
#  '자릿수',
#  '자바',
#  '자체',
#  '작성',
#  '재희',
#  '저',
#  '저자',
#  '저희',
#  '전',
#  '전공자',
#  '전문',
#  '전문가',
#  '전부',
#  '접',
#  '정규표현식',
#  '정리',
#  '정수',
#  '제',
#  '제시',
#  '제작',
#  '조건문',
#  '조금',
#  '조립',
#  '조언',
#  '좀',
#  '종류',
#  '종사',
#  '좌표',
#  '주로',
#  '주위',
#  '준비',
#  '중',
#  '증가',
#  '지금',
#  '지능',
#  '지식인',
#  '지원',
#  '진로',
#  '진행',
#  '질문',
#  '쪽',
#  '참고',
#  '책',
#  '처음',
#  '첨부',
#  '첫',
#  '초보',
#  '초심자',
#  '촬영',
#  '최고',
#  '최대',
#  '최선',
#  '최신',
#  '추가',
#  '추천',
#  '출력',
#  '출판',
#  '취미',
#  '취업',
#  '캡쳐',
#  '컨설팅',
#  '컴퓨터',
#  '컴퓨터언어',
#  '코드',
#  '코딩',
#  '클래스',
#  '클릭',
#  '키',
#  '타',
#  '타입',
#  '타카',
#  '터틀',
#  '텍스트',
#  '통합',
#  '통해',
#  '툴',
#  '특성',
#  '특유',
#  '파이선',
#  '파이썬',
#  '파일',
#  '파일이름',
#  '판',
#  '패키지',
#  '펍',
#  '편',
#  '폴더',
#  '표현',
#  '프로그래밍',
#  '프로그래밍언어',
#  '프로그램',
#  '프로젝트',
#  '하나',
#  '하나요',
#  '하드웨어',
#  '학생',
#  '학원',
#  '학점은행제',
#  '함수',
#  '해당',
#  '허수부',
#  '협업',
#  '형부',
#  '호출',
#  '혼자',
#  '홈페이지',
#  '확률',
#  '확인',
#  '환경',
#  '활동',
#  '활용',
#  '효과',
#  '효율',
#  '후',
#  '후기',
#  '후미',
#  '후보',
#  '흥미'}

# %%
# url = urlopen('https://search.naver.com/search.naver?where=kin&kin_display=10&qt=&title=0&&answer=0&grade=0&choice=0&sec=0&nso=so%3Ar%2Ca%3Aall%2Cp%3Aall&query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&c_id=&c_name=&sm=tab_pge&kin_start='+str(i))
# soup = BeautifulSoup(url, 'html.parser')

# QresultSet = soup.find_all('dt','question')
# AresultSet = soup.find_all('dd','answer')

# for result in QresultSet:
#     for i in result.find_all('a'):
#         print(i.text)

# for result in AresultSet:
#         print(result.text)

# for result in QresultSet:
#     for i in result.find_all('a'):
#         print(i.get_text())

# question = ""
# for result in QresultSet:
#     for i in result.find_all('a'):
#         question += i.text

# answer = ""
# for result in AresultSet:
#         answer += result.text

    # for anchor in soup.find_all('a'):
    #     print(anchor.get('href', '/'))
